# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as opt
from sklearn import preprocessing
pd.set_option('display.max_rows', 500) 
pd.set_option('display.max_rows', 500)

# %%
def read_data_file(filemame):
    df = pd.read_csv(filemame, header=None)
    df.columns = ["Exam1Score", "Exam2Score", "AdmitORNot"]
    df2 = df.copy(deep=True)
    return df

def segregate_x_y(df):
    df_x = df[["Exam1Score", "Exam2Score"]]  # single [] gives error in this case
    df_y = df[["AdmitORNot"]]  # if i put single [] then it return series and [[]] return dataframe
    return df_x, df_y

def segregate_x_into_pass_fail(df_x, df_y):
    mask_pass = df_y["AdmitORNot"] == 1
    df_x_pass = df_x[mask_pass]
    df_x_fail = df_x[~mask_pass]
    return df_x_pass, df_x_fail, mask_pass

def plot_pass_fail(df_x_pass, df_x_fail):
    plt.scatter(df_x_pass["Exam1Score"], df_x_pass["Exam2Score"], marker="o", color="green", label="Admitted")
    plt.scatter(df_x_fail["Exam1Score"], df_x_fail["Exam2Score"], marker="o", color="red", label="Not Admitted")
    plt.xlabel("Exam1 Score")
    plt.ylabel("Exam2 Score")
    plt.legend(loc="best")
    return plt

def fit_x(df_x, df_y):
    x = np.c_[np.ones(df_x.shape[0]), df_x] # this will change you data frame to numpy array
    theta = np.zeros((x.shape[1], 1))
    y = df_y.to_numpy()                     # here are are manually using function to convert dataframe to numpy array
    return x, y, theta

def z(x, theta):
    return np.dot(x, theta)

def sigmoid(Z):
    return 1 / (1 + np.exp(-Z))  # note outer brackets in denominator are important else it bad/wrong result.

def cost_function(theta, x, y):
    m = x.shape[0]
    h = sigmoid(z(x, theta))
    j = (1 / m) * (np.dot(np.log(h).T, -y) - np.dot(np.log(1 - h).T, (1 - y)))
    return j

def first_deri_j(theta, x, y):
    m = x.shape[0]
    h = sigmoid(z(x, theta))
    calculation = (1 / m) * (np.dot((h - y).T, x))
    return calculation.T

def accuracy(predicted_y, df_y):
    diff = predicted_y - df_y
    return (float(np.count_nonzero(diff)) / len(diff))

# %%
df = read_data_file("ex2data1.txt")
df_x, df_y = segregate_x_y(df)
df_x_pass, df_x_fail, mask = segregate_x_into_pass_fail(df_x, df_y)
plt = plot_pass_fail(df_x_pass, df_x_fail)

# %%
mask
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17    False
# 18     True
# 19     True
# 20    False
# 21     True
# 22    False
# 23    False
# 24     True
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 31     True
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40     True
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51     True
# 52     True
# 53    False
# 54    False
# 55    False
# 56     True
# 57    False
# 58     True
# 59     True
# 60     True
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# 66     True
# 67    False
# 68     True
# 69     True
# 70    False
# 71     True
# 72     True
# 73     True
# 74     True
# 75     True
# 76     True
# 77     True
# 78    False
# 79    False
# 80     True
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# 86    False
# 87     True
# 88     True
# 89    False
# 90     True
# 91     True
# 92    False
# 93     True
# 94     True
# 95     True
# 96     True
# 97     True
# 98     True
# 99     True
# Name: AdmitORNot, dtype: bool

# %%
df2 = df.copy(deep=True)
df2_x, df2_y = segregate_x_y(df2)
df2_x = preprocessing.scale(df2_x)

# %%
x, y, theta = fit_x(df2_x, df2_y)

# %%
initial_cost = cost_function(theta, x, y)
initial_cost
# Out:
# array([[0.69314718]])

# %%
def batch_graident_decent(theta, x, y, alpha = 0.03, convergence=0.01):
    cost_list = list()
    old_cost=0
    change_in_cost = 0
    i = 0
    while i < 1000:
        theta = theta - (alpha*first_deri_j(theta, x, y))
        cost = cost_function(theta, x, y)
        cost_list.append(cost.item(0,0))
        change_in_cost = cost - old_cost
        old_cost = cost
        i = i + 1
    return theta, i, cost_list

theta, i , cost_list = batch_graident_decent(theta, x, y)
print("New Theta from Graident descent = ", theta)
print("Number of iterations =", i)
print("cost with this theta is =",cost_function(theta, x, y) )
# Out:
# New Theta from Graident descent =  [[0.81208984]
#  [2.08437052]
#  [1.8912875 ]]
# Number of iterations = 1000
# cost with this theta is = [[0.24233685]]

# %%
df2_x_pass = df2_x[mask]
df2_x_fail = df2_x[~mask]

# %%
plt.scatter(df2_x_pass[:,0], df2_x_pass[:,1], marker="o", color="green", label="Admitted")
plt.scatter(df2_x_fail[:,0], df2_x_fail[:,1], marker="o", color="red", label="Not Admitted")
x1 = np.arange(  np.min(df2_x[:,0])  , np.max(df2_x[:,1])  )
x2 = -(theta[0] + theta[1] * x1) / theta[2]
plt.plot(x1, x2, c='k', label='reg line')
plt.xlabel("Exam1 Score")
plt.ylabel("Exam2 Score")
plt.legend(loc="best")

plt.show()

# %%
df2["probability"] = sigmoid(z(x, theta))

# %%
df2.loc[df2['probability'] >= .5  , 'ZeroOROne'] = 1
df2.loc[df2['probability']  < .5  , 'ZeroOROne'] = 0
df2.loc[df2['AdmitORNot'] == df2['ZeroOROne']   , "GoodorBadPrediction"    ] = "good-prediction"
df2.loc[df['AdmitORNot'] != df2['ZeroOROne']   , "GoodorBadPrediction"    ] = "bad-prediction"
df2
# Out:
#     Exam1Score  Exam2Score  AdmitORNot  probability  ZeroOROne  \
# 0    34.623660   78.024693           0     0.210768        0.0
# 1    30.286711   43.894998           0     0.005075        0.0
# 2    35.847409   72.902198           0     0.152836        0.0
# 3    60.182599   86.308552           1     0.907099        1.0
# 4    79.032736   75.344376           1     0.960327        1.0
# 5    45.083277   56.316372           0     0.082055        0.0
# 6    61.106665   96.511426           1     0.968380        1.0
# 7    75.024746   46.554014           1     0.452685        0.0
# 8    76.098787   87.420570           1     0.983794        1.0
# 9    84.432820   43.533393           1     0.625760        1.0
# 10   95.861555   38.225278           0     0.768796        1.0
# 11   75.013658   30.603263           0     0.139121        0.0
# 12   82.307053   76.481963           1     0.974802        1.0
# 13   69.364589   97.718692           1     0.988277        1.0
# 14   39.538339   76.036811           0     0.270019        0.0
# 15   53.971052   89.207350           1     0.870626        1.0
# 16   69.070144   52.740470           1     0.450638        0.0
# 17   67.946855   46.678574           0     0.281084        0.0
# 18   70.661510   92.927138           1     0.983437        1.0
# 19   76.978784   47.575964           1     0.531229        1.0
# 20   67.372028   42.838438           0     0.198805        0.0
# 21   89.676776   65.799366           1     0.966307        1.0
# 85   68.468522   85.594307           1     0.956799        1.0
# 86   42.075455   78.844786           0     0.393135        0.0
# 87   75.477702   90.424539           1     0.987212        1.0
# 88   78.635424   96.647427           1     0.995145        1.0
# 89   52.348004   60.769505           0     0.235571        0.0
# 90   94.094331   77.159105           1     0.993266        1.0
# 91   90.448551   87.508792           1     0.996529        1.0
# 92   55.482161   35.570703           0     0.031761        0.0
# 93   74.492692   84.845137           1     0.975148        1.0
# 94   89.845807   45.358284           1     0.783044        1.0
# 95   83.489163   48.380286           1     0.712643        1.0
# 96   42.261701   87.103851           1     0.606043        1.0
# 97   99.315009   68.775409           1     0.990971        1.0
# 98   55.340018   64.931938           1     0.394311        0.0
# 99   74.775893   89.529813           1     0.984922        1.0
#
#    GoodorBadPrediction
# 0      good-prediction
# 1      good-prediction
# 2      good-prediction
# 3      good-prediction
# 4      good-prediction
# 5      good-prediction
# 6      good-prediction
# 7       bad-prediction
# 8      good-prediction
# 9      good-prediction
# 10      bad-prediction
# 11     good-prediction
# 12     good-prediction
# 13     good-prediction
# 14     good-prediction
# 15     good-prediction
# 16      bad-prediction
# 17     good-prediction
# 18     good-prediction
# 19     good-prediction
# 20     good-prediction
# 21     good-prediction
# 22     good-prediction
# 23     good-prediction
# 24     good-prediction
# 25     good-prediction
# 26     good-prediction
# 27      bad-prediction
# 28     good-prediction
# 29     good-prediction
# 30     good-prediction
# 31     good-prediction
# 32     good-prediction
# 33      bad-prediction
# 34     good-prediction
# 35     good-prediction
# 36      bad-prediction
# 37     good-prediction
# 38     good-prediction
# 39     good-prediction
# 40     good-prediction
# 41     good-prediction
# 42     good-prediction
# 43     good-prediction
# 44     good-prediction
# 45     good-prediction
# 46     good-prediction
# 47     good-prediction
# 48     good-prediction
# 49     good-prediction
# 50     good-prediction
# 51     good-prediction
# 52     good-prediction
# 53     good-prediction
# 54     good-prediction
# 55     good-prediction
# 56     good-prediction
# 57      bad-prediction
# 58     good-prediction
# 59     good-prediction
# 60     good-prediction
# 61     good-prediction
# 62     good-prediction
# 63     good-prediction
# 64     good-prediction
# 65     good-prediction
# 66     good-prediction
# 67     good-prediction
# 68     good-prediction
# 69     good-prediction
# 70     good-prediction
# 71     good-prediction
# 72     good-prediction
# 73     good-prediction
# 74     good-prediction
# 75     good-prediction
# 76     good-prediction
# 77     good-prediction
# 78     good-prediction
# 79      bad-prediction
# 80     good-prediction
# 81     good-prediction
# 82     good-prediction
# 83      bad-prediction
# 84     good-prediction
# 85     good-prediction
# 86     good-prediction
# 87     good-prediction
# 88     good-prediction
# 89     good-prediction
# 90     good-prediction
# 91     good-prediction
# 92     good-prediction
# 93     good-prediction
# 94     good-prediction
# 95     good-prediction
# 96     good-prediction
# 97     good-prediction
# 98      bad-prediction
# 99     good-prediction

# %%
df2.to_csv("Manual_result.csv", sep=',', encoding='utf-8')

# %%
# Plotting a cost function.
i = range(1,len(cost_list)+1)
len(cost_list)
plt.plot(i, cost_list, color="green", label="Cost")
plt.xlabel("Number of Iterations")
plt.ylabel("Cost")
plt.legend(loc="best")
plt.grid()
plt.show()
